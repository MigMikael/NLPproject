# %% [markdown]
# # 2

# %%
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
len(text1)
# Out:
# 260819

# %%
[w for w in text1 if w.startswith("I") and w.lower() != "i" and w.lower() != "it" and w.lower() != "its" and w.lower() != "is" and w.lower() != "in" and w.lower() != "if"]
# Out:
# ['IAN',
#  'ICELANDIC',
#  'ISAIAH',
#  'Indian',
#  'IBID',
#  'Immense',
#  'ISLANDS',
#  'IBID',
#  'INTO',
#  'ICELAND',
#  'Io',
#  'Io',
#  'IBID',
#  'India',
#  'Ishmael',
#  'Indian',
#  'Inlanders',
#  'ISHMAEL',
#  'Ishmael',
#  'Ishmael',
#  'Inn',
#  'Ishmael',
#  'Ishmael',
#  'Inn',
#  'Inn',
#  'Inn',
#  'Iceland',
#  'Indian',
#  'Ignorance',
#  'Indeed',
#  'Instantly',
#  'Indian',
#  'Indian',
#  'Indian',
#  'Isle',
#  'Indies',
#  'Insurance',
#  'Ishmael',
#  'Inn',
#  'Ishmael',
#  'Impossible',
#  'Indian',
#  'Illinois',
#  'Indian',
#  'Indian',
#  'Indian',
#  'India',
#  'Inn',
#  'Innkeeper',
#  'ILE',
#  'Ishmael',
#  'Indians',
#  'Indolence',
#  'Ishmael',
#  'Ishmael',
#  'Ishmael',
#  'Island',
#  'Indian',
#  'Indeed',
#  'IMPOSING',
#  'Indies',
#  'Indian',
#  'Indian',
#  'Indian',
#  'Islands',
#  'Islanders',
#  'Islanders',
#  'ISOLATOES',
#  'ISOLATO',
#  'Isolatoes',
#  'Indian',
#  'Indian',
#  'Inward',
#  'Impenetrable',
#  'II',
#  'III',
#  'II',
#  'III',
#  'IV',
#  'II',
#  'Indian',
#  'III',
#  'IV',
#  'II',
#  'II',
#  'III',
#  'IV',
#  'II',
#  'II',
#  'II',
#  'II',
#  'III',
#  'Irish',
#  'II',
#  'IV',
#  'II',
#  'II',
#  'III',
#  'II',
#  'III',
#  'III',
#  'Indeed',
#  'III',
#  'II',
#  'III',
#  'III',
#  'Indian',
#  'Iceberg',
#  'Icelandic',
#  'Indeed',
#  'Inert',
#  'Imperial',
#  'Indian',
#  'Indian',
#  'Island',
#  'Icebergs',
#  'Icelandic',
#  'Indian',
#  'Iron',
#  'Insufferable',
#  'Indian',
#  'ICELAND',
#  'ISLAND',
#  'Ishmael',
#  'Ishmael',
#  'Iroquois',
#  'Indian',
#  'Indians',
#  'Indian',
#  'Ishmael',
#  'Ishmael',
#  'Indian',
#  'Indian',
#  'Islands',
#  'Indian',
#  'Instantly',
#  'Indian',
#  'Instantly',
#  'Islands',
#  'Island',
#  'INN',
#  'Interweaving',
#  'Inn',
#  'Inn',
#  'Intolerably',
#  'Immediately',
#  'Indian',
#  'Isabella',
#  'Inquisition',
#  'Islanders',
#  'Islanders',
#  'Inn',
#  'India',
#  'Italian',
#  'III',
#  'Iron',
#  'Iroquois',
#  'Islands',
#  'India',
#  'Indeed',
#  'Indian',
#  'Indian',
#  'Indian',
#  'Indians',
#  'Indian',
#  'Ingin',
#  'Into',
#  'Into',
#  'Italian',
#  'Indian',
#  'Indian',
#  'Indian',
#  'Italian',
#  'Israelites',
#  'Indian',
#  'Indiamen',
#  'Isthmus',
#  'Indian',
#  'Indian',
#  'Inserting',
#  'Indian',
#  'Indian',
#  'Indian',
#  'Indian',
#  'Indian',
#  'Ishmael',
#  'Indeed',
#  'Impossible',
#  'Indiaman',
#  'Indian',
#  'Immediately',
#  'Indian',
#  'Italy',
#  'Israel',
#  'Instead',
#  'Italian',
#  'Isaiah',
#  'Indian',
#  'Indian',
#  'Islands',
#  'Indian',
#  'Indian',
#  'Indians',
#  'Instantly',
#  'II',
#  'Ireland',
#  'India',
#  'Issuing',
#  'Instantly',
#  'Icy',
#  'Indian',
#  'Immemorial',
#  'Improving',
#  'Ishmael',
#  'Ishmael',
#  'Ishmael',
#  'Icy',
#  'Inasmuch',
#  'Iceland',
#  'Illinois',
#  'Illinois',
#  'Indian',
#  'Isles',
#  'IVORY',
#  'IVORY',
#  'Imprimis',
#  'Isles',
#  'Island',
#  'Indian',
#  'Icy',
#  'Ifs',
#  'Isles',
#  'Island',
#  'Immortal',
#  'Insurance',
#  'Instantly',
#  'Instances',
#  'Isle',
#  'Isle',
#  'Innocents',
#  'Indeed',
#  'Isle',
#  'Immediately',
#  'Invisible',
#  'Indian',
#  'Indian',
#  'Indian',
#  'Inferable',
#  'Impiety',
#  'Indian',
#  'Ixion']

# %%
ww = [w for w in text1 if w.istitle() and len(w) > 1]

# %%
len(ww)
# Out:
# 16063

# %%
ww
# Out:
# ['Moby',
#  'Dick',
#  'Herman',
#  'Melville',
#  'Supplied',
#  'Late',
#  'Consumptive',
#  'Usher',
#  'Grammar',
#  'School',
#  'The',
#  'Usher',
#  'He',
#  'He',
#  'While',
#  'Sw',
#  'Dan',
#  'This',
#  'Dan',
#  'It',
#  'Dut',
#  'Ger',
#  'Supplied',
#  'Sub',
#  'Sub',
#  'Librarian',
#  'It',
#  'Sub',
#  'Sub',
#  'Vaticans',
#  'Therefore',
#  'Far',
#  'As',
#  'Leviathan',
#  'So',
#  'Sub',
#  'Sub',
#  'Thou',
#  'Pale',
#  'Sherry',
#  'Give',
#  'Sub',
#  'Subs',
#  'For',
#  'Would',
#  'Hampton',
#  'Court',
#  'Tuileries',
#  'But',
#  'Gabriel',
#  'Michael',
#  'Raphael',
#  'Here',
#  'And',
#  'God',
#  'Leviathan',
#  'One',
#  'Now',
#  'Lord',
#  'Jonah',
#  'There',
#  'Leviathan',
#  'In',
#  'Lord',
#  'Leviathan',
#  'Leviathan',
#  'And',
#  'The',
#  'Indian',
#  'Sea',
#  'Whales',
#  'Whirlpooles',
#  'Balaene',
#  'Scarcely',
#  'Whales',
#  'Among',
#  'This',
#  'He',
#  'The',
#  'He',
#  'And',
#  'Let',
#  'Old',
#  'Nick',
#  'Leviathan',
#  'Moses',
#  'Job',
#  'This',
#  'The',
#  'Leviathan',
#  'Touching',
#  'They',
#  'The',
#  'Very',
#  'Which',
#  'Mote',
#  'To',
#  'Dinting',
#  'Like',
#  'Immense',
#  'What',
#  'Hosmannus',
#  'Nescio',
#  'Like',
#  'Spencer',
#  'Talus',
#  'He',
#  'Their',
#  'And',
#  'By',
#  'Leviathan',
#  'Commonwealth',
#  'State',
#  'Latin',
#  'Civitas',
#  'Silly',
#  'Mansoul',
#  'That',
#  'Leviathan',
#  'God',
#  'Created',
#  'There',
#  'Leviathan',
#  'Hugest',
#  'Stretched',
#  'And',
#  'Draws',
#  'The',
#  'So',
#  'The',
#  'Leviathan',
#  'And',
#  'Which',
#  'While',
#  'In',
#  'Here',
#  'We',
#  'Elbe',
#  'The',
#  'Jonas',
#  'Whale',
#  'Some',
#  'They',
#  'Shetland',
#  'One',
#  'Spitzbergen',
#  'Several',
#  'Fife',
#  'Anno',
#  'The',
#  'Pitferren',
#  'Myself',
#  'Sperma',
#  'Whales',
#  'God',
#  'We',
#  'To',
#  'We',
#  'Oft',
#  'Tho',
#  'If',
#  'The',
#  'If',
#  'In',
#  'Asiatics',
#  'They',
#  'The',
#  'They',
#  'The',
#  'Spermacetti',
#  'Whale',
#  'Nantuckois',
#  'And',
#  'Spain',
#  'Europe',
#  'And',
#  'Soon',
#  'Rodmond',
#  'The',
#  'Bright',
#  'And',
#  'To',
#  'Around',
#  'So',
#  'The',
#  'Up',
#  'To',
#  'Ten',
#  'The',
#  'London',
#  'Bridge',
#  'The',
#  'In',
#  'Spermacetti',
#  'Whales',
#  'May',
#  'In',
#  'Floundered',
#  'Fishes',
#  'Which',
#  'Had',
#  'Leviathan',
#  'To',
#  'Gather',
#  'Led',
#  'And',
#  'Assaulted',
#  'Whales',
#  'With',
#  'Io',
#  'Paean',
#  'Io',
#  'To',
#  'Not',
#  'In',
#  'Atlantic',
#  'Not',
#  'Flounders',
#  'Polar',
#  'Sea',
#  'In',
#  'Susan',
#  'Gothic',
#  'Arch',
#  'She',
#  'Pacific',
#  'No',
#  'Sir',
#  'Right',
#  'Whale',
#  'Tom',
#  'Christian',
#  'He',
#  'The',
#  'Berlin',
#  'Gazette',
#  'My',
#  'God',
#  'Mr',
#  'Chace',
#  'The',
#  'Now',
#  'And',
#  'As',
#  'The',
#  'English',
#  'Sometimes',
#  'Mad',
#  'Sperm',
#  'Whale',
#  'It',
#  'Sperm',
#  'Whale',
#  'The',
#  'Cachalot',
#  'Sperm',
#  'Whale',
#  'True',
#  'Whale',
#  'Greenland',
#  'Right',
#  'Whale',
#  'October',
#  'There',
#  'Where',
#  'Three',
#  'Raise',
#  'Steady',
#  'Steady',
#  'Mast',
#  'Do',
#  'Ay',
#  'Sperm',
#  'Whales',
#  'There',
#  'There',
#  'Sing',
#  'Ay',
#  'Ay',
#  'There',
#  'How',
#  'Two',
#  'Thunder',
#  'Call',
#  'The',
#  'Whale',
#  'Globe',
#  'Nantucket',
#  'Being',
#  'Nantucket',
#  'Mr',
#  'Webster',
#  'National',
#  'There',
#  'National',
#  'The',
#  'If',
#  'Samuel',
#  'The',
#  'Dutch',
#  'English',
#  'Northern',
#  'Ocean',
#  'India',
#  'These',
#  'North',
#  'West',
#  'Passage',
#  'It',
#  'The',
#  'Pedestrians',
#  'London',
#  'It',
#  'It',
#  'Whaling',
#  'American',
#  'Suddenly',
#  'It',
#  'The',
#  'Whale',
#  'On',
#  'Terra',
#  'Del',
#  'Fuego',
#  'Stern',
#  'Sperm',
#  'Whale',
#  'Stern',
#  'So',
#  'While',
#  'Oh',
#  'Whale',
#  'In',
#  'And',
#  'King',
#  'Loomings',
#  'Call',
#  'Ishmael',
#  'Some',
#  'It',
#  'Whenever',
#  'November',
#  'This',
#  'With',
#  'Cato',
#  'There',
#  'If',
#  'There',
#  'Manhattoes',
#  'Indian',
#  'Right',
#  'Its',
#  'Look',
#  'Circumambulate',
#  'Sabbath',
#  'Go',
#  'Corlears',
#  'Hook',
#  'Coenties',
#  'Slip',
#  'Whitehall',
#  'What',
#  'Posted',
#  'Some',
#  'China',
#  'But',
#  'How',
#  'Are',
#  'What',
#  'But',
#  'Strange',
#  'Nothing',
#  'No',
#  'They',
#  'And',
#  'Inlanders',
#  'Yet',
#  'Tell',
#  'Once',
#  'Say',
#  'Take',
#  'There',
#  'Let',
#  'Should',
#  'American',
#  'Yes',
#  'But',
#  'He',
#  'Saco',
#  'What',
#  'There',
#  'Deep',
#  'But',
#  'Go',
#  'Prairies',
#  'June',
#  'Tiger',
#  'Water',
#  'Were',
#  'Niagara',
#  'Why',
#  'Tennessee',
#  'Rockaway',
#  'Beach',
#  'Why',
#  'Why',
#  'Why',
#  'Persians',
#  'Why',
#  'Greeks',
#  'Jove',
#  'Surely',
#  'And',
#  'Narcissus',
#  'But',
#  'It',
#  'Now',
#  'For',
#  'Besides',
#  'Commodore',
#  'Captain',
#  'Cook',
#  'For',
#  'It',
#  'And',
#  'It',
#  'Egyptians',
#  'No',
#  'True',
#  'May',
#  'And',
#  'It',
#  'Van',
#  'Rensselaers',
#  'Randolphs',
#  'Hardicanutes',
#  'And',
#  'The',
#  'Seneca',
#  'Stoics',
#  'But',
#  'What',
#  'What',
#  'New',
#  'Testament',
#  'Do',
#  'Gabriel',
#  'Who',
#  'Tell',
#  'Well',
#  'Again',
#  'On',
#  'And',
#  'The',
#  'But',
#  'The',
#  'Ah',
#  'Finally',
#  'For',
#  'Pythagorean',
#  'Commodore',
#  'He',
#  'In',
#  'But',
#  'Fates',
#  'And',
#  'Providence',
#  'It',
#  'Though',
#  'Fates',
#  'Chief',
#  'Such',
#  'Then',
#  'Patagonian',
#  'With',
#  'Not',
#  'By',
#  'The',
#  'Carpet',
#  'Bag',
#  'Cape',
#  'Horn',
#  'Pacific',
#  'Quitting',
#  'Manhatto',
#  'New',
#  'Bedford',
#  'It',
#  'Saturday',
#  'December',
#  'Much',
#  'Nantucket',
#  'Monday',
#  'As',
#  'New',
#  'Bedford',
#  'For',
#  'Nantucket',
#  'Besides',
#  'New',
#  'Bedford',
#  'Nantucket',
#  'Nantucket',
#  'Tyre',
#  'Carthage',
#  'American',
#  'Where',
#  'Nantucket',
#  'Red',
#  'Men',
#  'Leviathan',
#  'And',
#  'Nantucket',
#  'Now',
#  'New',
#  'Bedford',
#  'It',
#  'With',
#  'So',
#  'Ishmael',
#  'Ishmael',
#  'With',
#  'The',
#  'Crossed',
#  'Harpoons',
#  'Further',
#  'Sword',
#  'Fish',
#  'Inn',
#  'Too',
#  'But',
#  'Ishmael',
#  'So',
#  'Such',
#  'At',
#  'But',
#  'It',
#  'Ha',
#  'Gomorrah',
#  'But',
#  'The',
#  'Crossed',
#  'Harpoons',
#  'The',
#  'Sword',
#  'Fish',
#  'The',
#  'Trap',
#  'However',
#  'It',
#  'Black',
#  'Parliament',
#  'Tophet',
#  'Angel',
#  'Doom',
#  'It',
#  'Ha',
#  'Ishmael',
#  'Wretched',
#  'The',
#  'Trap',
#  'Moving',
#  'The',
#  'Spouter',
#  'Inn',
#  'Peter',
#  'Coffin',
#  'Coffin',
#  'Spouter',
#  'Rather',
#  'But',
#  'Nantucket',
#  'Peter',
#  'As',
#  'It',
#  'It',
#  'Euroclydon',
#  'Paul',
#  'Euroclydon',
#  'In',
#  'Euroclydon',
#  'Death',
#  'True',
#  'Yes',
#  'What',
#  'But',
#  'The',
#  'Poor',
#  'Lazarus',
#  'Euroclydon',
#  'Euroclydon',
#  'Dives',
#  'What',
#  'Orion',
#  'Let',
#  'But',
#  'Lazarus',
#  'Can',
#  'Would',
#  'Lazarus',
#  'Sumatra',
#  'Would',
#  'Now',
#  'Lazarus',
#  'Dives',
#  'Moluccas',
#  'Yet',
#  'Dives',
#  'Czar',
#  'But',
#  'Let',
#  'Spouter',
#  'The',
#  'Spouter',
#  'Inn',
#  'Entering',
#  'Spouter',
#  'Inn',
#  'On',
#  'Such',
#  'New',
#  'England',
#  'But',
#  'But',
#  'Yet',
#  'Ever',
#  'It',
#  'Black',
#  'Sea',
#  'It',
#  'It',
#  'It',
#  'Hyperborean',
#  'It',
#  'Time',
#  'But',
#  'But',
#  'In',
#  'The',
#  'Cape',
#  'Horner',
#  'The',
#  'Some',
#  'You',
#  'Mixed',
#  'Some',
#  'With',
#  'Nathan',
#  'Swain',
#  'And',
#  'Javan',
#  'Cape',
#  'Blanco',
#  'The',
#  'Crossing',
#  'On',
#  'Projecting',
#  'Be',
#  'Within',
#  'Jonah',
#  'Abominable',
#  'Though',
#  'Parallel',
#  'Fill',
#  'Cape',
#  'Horn',
#  'Upon',
#  'But',
#  'All',
#  'Supper',
#  'Supper',
#  'Battery',
#  'At',
#  'He',
#  'At',
#  'It',
#  'Iceland',
#  'Nothing',
#  'We',
#  'But',
#  'One',
#  'My',
#  'Landlord',
#  'Oh',
#  'He',
#  'The',
#  'Where',
#  'Is',
#  'He',
#  'At',
#  'Supper',
#  'Presently',
#  'Starting',
#  'That',
#  'Grampus',
#  'Hurrah',
#  'Feegees',
#  'Enveloped',
#  'Labrador',
#  'They',
#  'No',
#  'Jonah',
#  'One',
#  'Jonah',
#  'Labrador',
#  'The',
#  'This',
#  'He',
#  'His',
#  'His',
#  'Southerner',
#  'Alleghanian',
#  'Ridge',
#  'Virginia',
#  'When',
#  'In',
#  'Bulkington',
#  'Bulkington',
#  'Bulkington',
#  'It',
#  'No',
#  'In',
#  'And',
#  'Nor',
#  'Kings',
#  'To',
#  'The',
#  'It',
#  'Besides',
#  'Suppose',
#  'Landlord',
#  'Just',
#  'But',
#  'Skrimshander',
#  'So',
#  'The',
#  'The',
#  'So',
#  'But',
#  'But',
#  'The',
#  'It',
#  'For',
#  'Still',
#  'Thinks',
#  'But',
#  'Landlord',
#  'It',
#  'The',
#  'No',
#  'But',
#  'Can',
#  'What',
#  'Do',
#  'Saturday',
#  'Sunday',
#  'That',
#  'With',
#  'With',
#  'May',
#  'It',
#  'Broke',
#  'Sartain',
#  'Landlord',
#  'Mt',
#  'Hecla',
#  'You',
#  'And',
#  'And',
#  'Wall',
#  'But',
#  'New',
#  'Zealand',
#  'Sunday',
#  'He',
#  'Sunday',
#  'This',
#  'Saturday',
#  'Sabbath',
#  'Depend',
#  'He',
#  'But',
#  'Sal',
#  'There',
#  'Why',
#  'Sal',
#  'Sam',
#  'Johnny',
#  'But',
#  'Sam',
#  'Arter',
#  'Sal',
#  'Come',
#  'But',
#  'Sunday',
#  'There',
#  'Folding',
#  'Though',
#  'Of',
#  'Likewise',
#  'But',
#  'Indian',
#  'There',
#  'South',
#  'American',
#  'But',
#  'Christian',
#  'After',
#  'But',
#  'Whether',
#  'At',
#  'Nod',
#  'Lord',
#  'But',
#  'Holding',
#  'New',
#  'Zealand',
#  'This',
#  'Such',
#  'It',
#  'Yes',
#  'But',
#  'They',
#  'At',
#  'And',
#  'It',
#  'But',
#  'To',
#  'However',
#  'South',
#  'Seas',
#  'Now',
#  'But',
#  'Placing',
#  'New',
#  'Zealand',
#  'He',
#  'There',
#  'His',
#  'Had',
#  'Even',
#  'Ignorance',
#  'In',
#  'Meanwhile',
#  'As',
#  'Thirty',
#  'Years',
#  'War',
#  'Still',
#  'It',
#  'South',
#  'Seas',
#  'Christian',
#  'He',
#  'But',
#  'Going',
#  'Congo',
#  'Remembering',
#  'But',
#  'For',
#  'The',
#  'Congo',
#  'First',
#  'Presently',
#  'But',
#  'All',
#  'At',
#  'All',
#  'But',
#  'Taking',
#  'The',
#  'Stammering',
#  'But',
#  'Who',
#  'And',
#  'Landlord',
#  'God',
#  'Peter',
#  'Coffin',
#  'Landlord',
#  'Watch',
#  'Coffin',
#  'Angels',
#  'Speak',
#  'But',
#  'Don',
#  'Queequeg',
#  'Stop',
#  'Queequeg',
#  'Me',
#  'Queequeg',
#  'You',
#  'He',
#  'For',
#  'What',
#  'Better',
#  'Christian',
#  'Landlord',
#  'But',
#  'It',
#  'Besides',
#  'This',
#  'Queequeg',
#  'Good',
#  'The',
#  'Counterpane',
#  'Upon',
#  'Queequeg',
#  'You',
#  'The',
#  'Cretan',
#  'Indeed',
#  'Queequeg',
#  'My',
#  'Let',
#  'When',
#  'The',
#  'June',
#  'But',
#  'Sixteen',
#  'And',
#  'But',
#  'For',
#  'At',
#  'Instantly',
#  'My',
#  'For',
#  'Nay',
#  'Now',
#  'Queequeg',
#  'But',
#  'For',
#  'Queequeg',
#  'Throwing',
#  'Queequeg',
#  'Queequeg',
#  'At',
#  'Newfoundland',
#  'Meanwhile',
#  'When',
#  'Thinks',
#  'Queequeg',
#  'Queequeg',
#  'Nevertheless',
#  'Queequeg',
#  'He',
#  'What',
#  'But',
#  'Queequeg',
#  'He',
#  'His',
#  'He',
#  'If',
#  'At',
#  'Seeing',
#  'Queequeg',
#  'He',
#  'At',
#  'Christian',
#  'Queequeg',
#  'He',
#  'Thinks',
#  'Queequeg',
#  'Rogers',
#  'Afterwards',
#  'The',
#  'Breakfast',
#  'However',
#  'So',
#  'And',
#  'The',
#  'They',
#  'You',
#  'This',
#  'Indian',
#  'That',
#  'In',
#  'But',
#  'Queequeg',
#  'Andes',
#  'Grub',
#  'They',
#  'Not',
#  'Ledyard',
#  'New',
#  'England',
#  'Mungo',
#  'Park',
#  'Scotch',
#  'But',
#  'Siberia',
#  'Ledyard',
#  'Africa',
#  'Mungo',
#  'Still',
#  'These',
#  'And',
#  'Yes',
#  'Green',
#  'Mountains',
#  ...]

# %% [markdown]
# # 3

# %%
from nltk.corpus import brown

brown.categories()
# Out:
# ['adventure',
#  'belles_lettres',
#  'editorial',
#  'fiction',
#  'government',
#  'hobbies',
#  'humor',
#  'learned',
#  'lore',
#  'mystery',
#  'news',
#  'religion',
#  'reviews',
#  'romance',
#  'science_fiction']

# %%
def lexical_diversity(text):
    print(len(set(text)))
    print(len(text))
    return len(set(text)) / len(text)

# %%
adventure_text = brown.words(categories='adventure')
adventure_text = [w.lower() for w in adventure_text]

# %%
lexical_diversity(adventure_text)
# Out:
# 8289
# 69342
# 0.11953794237258804

# %%
fiction_text = brown.words(categories='fiction')
fiction_text = [w.lower() for w in fiction_text]
lexical_diversity(fiction_text)
# Out:
# 8680
# 68488
# 0.1267375306623058

# %%
news_text = brown.words(categories='news')
news_text = [w.lower() for w in news_text]
lexical_diversity(news_text)
# Out:
# 13112
# 100554
# 0.13039759731089762

# %%
reviews_text = brown.words(categories='reviews')
reviews_text = [w.lower() for w in reviews_text]
lexical_diversity(reviews_text)
# Out:
# 8069
# 40704
# 0.19823604559748428

# %%
religion_text = brown.words(categories='religion')
religion_text = [w.lower() for w in religion_text]
lexical_diversity(religion_text)
# Out:
# 5931
# 39399
# 0.15053681565521967

# %%
romance_text = brown.words(categories='romance')
romance_text = [w.lower() for w in romance_text]
lexical_diversity(romance_text)
# Out:
# 7883
# 70022
# 0.11257890377309988

# %% [markdown]
# # 4

# %%
import nltk
from nltk.corpus import stopwords

# %%
def unknown(text):
    text_vocab = set(w.lower() for w in text if w.isalpha())
    english_vocab = set(w.lower() for w in nltk.corpus.words.words())
    stop_word = set(w.lower() for w in stopwords.words('english'))
    unusual = text_vocab - english_vocab - stop_word
    print(len(unusual))
    #return sorted(unusual)

# %%
unknown(nltk.corpus.webtext.words())
# Out:
# 7521

# %% [markdown]
# # 8

# %%
sent = "The quick brown fox jumps over the lazy dog"
[w.lower() for w in sent.split() if len(w) == 3]
# Out:
# ['the', 'fox', 'the', 'dog']

# %% [markdown]
# # 9

# %%
from nltk.corpus import inaugural
inaugural.fileids()
# Out:
# ['1789-Washington.txt',
#  '1793-Washington.txt',
#  '1797-Adams.txt',
#  '1801-Jefferson.txt',
#  '1805-Jefferson.txt',
#  '1809-Madison.txt',
#  '1813-Madison.txt',
#  '1817-Monroe.txt',
#  '1821-Monroe.txt',
#  '1825-Adams.txt',
#  '1829-Jackson.txt',
#  '1833-Jackson.txt',
#  '1837-VanBuren.txt',
#  '1841-Harrison.txt',
#  '1845-Polk.txt',
#  '1849-Taylor.txt',
#  '1853-Pierce.txt',
#  '1857-Buchanan.txt',
#  '1861-Lincoln.txt',
#  '1865-Lincoln.txt',
#  '1869-Grant.txt',
#  '1873-Grant.txt',
#  '1877-Hayes.txt',
#  '1881-Garfield.txt',
#  '1885-Cleveland.txt',
#  '1889-Harrison.txt',
#  '1893-Cleveland.txt',
#  '1897-McKinley.txt',
#  '1901-McKinley.txt',
#  '1905-Roosevelt.txt',
#  '1909-Taft.txt',
#  '1913-Wilson.txt',
#  '1917-Wilson.txt',
#  '1921-Harding.txt',
#  '1925-Coolidge.txt',
#  '1929-Hoover.txt',
#  '1933-Roosevelt.txt',
#  '1937-Roosevelt.txt',
#  '1941-Roosevelt.txt',
#  '1945-Roosevelt.txt',
#  '1949-Truman.txt',
#  '1953-Eisenhower.txt',
#  '1957-Eisenhower.txt',
#  '1961-Kennedy.txt',
#  '1965-Johnson.txt',
#  '1969-Nixon.txt',
#  '1973-Nixon.txt',
#  '1977-Carter.txt',
#  '1981-Reagan.txt',
#  '1985-Reagan.txt',
#  '1989-Bush.txt',
#  '1993-Clinton.txt',
#  '1997-Clinton.txt',
#  '2001-Bush.txt',
#  '2005-Bush.txt',
#  '2009-Obama.txt']
